# %%
# DELIVERABLE 1

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import citipy
from citipy import citipy

# 3 Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
citipy
# Out:
# <module 'citipy.citipy' from '/Users/davidnathanael/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/citipy/citipy.py'>

# %%
# 4 Create a list for holding the cities using citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# 5 Perform API call with the OpenWeatherMap
# Import the requests library.
import requests

# Import the Weather API key.
from config import weather_api_key


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6 Run an API request for each of the cities.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. Using enumerate() method.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | gat
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | cabo san lucas
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | burnie
# Processing Record 11 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | honiara
# Processing Record 17 of Set 1 | valenca
# Processing Record 18 of Set 1 | husavik
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | baiao
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | katha
# City not found. Skipping...
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | iranshahr
# Processing Record 34 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | huntsville
# Processing Record 38 of Set 1 | kieta
# Processing Record 39 of Set 1 | sofiyivka
# Processing Record 40 of Set 1 | morvi
# Processing Record 41 of Set 1 | san cristobal
# Processing Record 42 of Set 1 | shenjiamen
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | gornopravdinsk
# Processing Record 2 of Set 2 | saint anthony
# Processing Record 3 of Set 2 | san ramon
# Processing Record 4 of Set 2 | puerto baquerizo moreno
# Processing Record 5 of Set 2 | ulladulla
# Processing Record 6 of Set 2 | mehamn
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 2 | srednekolymsk
# Processing Record 12 of Set 2 | sharan
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | san policarpo
# Processing Record 15 of Set 2 | vestmannaeyjar
# Processing Record 16 of Set 2 | ternate
# Processing Record 17 of Set 2 | cayenne
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | otradnoye
# Processing Record 20 of Set 2 | bestobe
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | alta floresta
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | hongan
# City not found. Skipping...
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | asau
# Processing Record 29 of Set 2 | fare
# Processing Record 30 of Set 2 | lasa
# Processing Record 31 of Set 2 | teguise
# Processing Record 32 of Set 2 | matay
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | khandyga
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | tres picos
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | clyde river
# Processing Record 39 of Set 2 | chandler
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | port macquarie
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | karlskoga
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | brae
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | maneadero
# Processing Record 1 of Set 3 | kundla
# Processing Record 2 of Set 3 | port hardy
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | jining
# Processing Record 5 of Set 3 | okhotsk
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | sorong
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | newport
# Processing Record 11 of Set 3 | vao
# Processing Record 12 of Set 3 | omsukchan
# Processing Record 13 of Set 3 | seoul
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | pangnirtung
# Processing Record 16 of Set 3 | mokhsogollokh
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | mareeba
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | paamiut
# Processing Record 23 of Set 3 | isiro
# Processing Record 24 of Set 3 | samoded
# Processing Record 25 of Set 3 | lovington
# Processing Record 26 of Set 3 | manakara
# Processing Record 27 of Set 3 | maryville
# Processing Record 28 of Set 3 | smolenka
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | hobyo
# Processing Record 31 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | fereydun kenar
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | mwene-ditu
# Processing Record 36 of Set 3 | houma
# Processing Record 37 of Set 3 | smithers
# Processing Record 38 of Set 3 | ivybridge
# Processing Record 39 of Set 3 | gidole
# Processing Record 40 of Set 3 | namibe
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | boddam
# Processing Record 43 of Set 3 | uyuni
# Processing Record 44 of Set 3 | glendive
# Processing Record 45 of Set 3 | wuda
# Processing Record 46 of Set 3 | bonfim
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 3 | najran
# Processing Record 1 of Set 4 | puerto ayora
# Processing Record 2 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 4 | port hueneme
# Processing Record 4 of Set 4 | krasnoselkup
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | shubarkuduk
# Processing Record 7 of Set 4 | maues
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | stykkisholmur
# Processing Record 10 of Set 4 | taoudenni
# Processing Record 11 of Set 4 | kitimat
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | santiago del estero
# Processing Record 15 of Set 4 | hongjiang
# Processing Record 16 of Set 4 | moerai
# Processing Record 17 of Set 4 | saint-louis
# Processing Record 18 of Set 4 | hassleholm
# Processing Record 19 of Set 4 | gizo
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | fallon
# Processing Record 22 of Set 4 | escanaba
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | tahe
# Processing Record 26 of Set 4 | thinadhoo
# Processing Record 27 of Set 4 | devonport
# Processing Record 28 of Set 4 | comodoro rivadavia
# Processing Record 29 of Set 4 | porto belo
# Processing Record 30 of Set 4 | odweyne
# Processing Record 31 of Set 4 | flin flon
# Processing Record 32 of Set 4 | hirara
# Processing Record 33 of Set 4 | half moon bay
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 4 | parkes
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | praia
# Processing Record 38 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | at-bashi
# Processing Record 40 of Set 4 | sur
# Processing Record 41 of Set 4 | port-gentil
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | luanda
# Processing Record 45 of Set 4 | nikolskoye
# Processing Record 46 of Set 4 | mar del plata
# Processing Record 47 of Set 4 | nahariyya
# Processing Record 48 of Set 4 | toro
# Processing Record 49 of Set 4 | camana
# Processing Record 50 of Set 4 | bambous virieux
# Processing Record 1 of Set 5 | dayong
# Processing Record 2 of Set 5 | tiarei
# Processing Record 3 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 5 | monroe
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | nishihara
# Processing Record 7 of Set 5 | maragogi
# Processing Record 8 of Set 5 | pangody
# Processing Record 9 of Set 5 | qaqortoq
# Processing Record 10 of Set 5 | peniche
# Processing Record 11 of Set 5 | kidal
# Processing Record 12 of Set 5 | xining
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | bonthe
# Processing Record 15 of Set 5 | manyana
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | jati
# Processing Record 18 of Set 5 | sao filipe
# Processing Record 19 of Set 5 | lebu
# Processing Record 20 of Set 5 | tombouctou
# Processing Record 21 of Set 5 | bagdarin
# Processing Record 22 of Set 5 | oriximina
# Processing Record 23 of Set 5 | tabou
# Processing Record 24 of Set 5 | dunda
# Processing Record 25 of Set 5 | buchanan
# Processing Record 26 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 27 of Set 5 | nouadhibou
# Processing Record 28 of Set 5 | hukuntsi
# Processing Record 29 of Set 5 | tumut
# Processing Record 30 of Set 5 | cacapava do sul
# Processing Record 31 of Set 5 | cabra
# Processing Record 32 of Set 5 | poum
# Processing Record 33 of Set 5 | sorland
# Processing Record 34 of Set 5 | caravelas
# Processing Record 35 of Set 5 | bengkulu
# Processing Record 36 of Set 5 | vila
# Processing Record 37 of Set 5 | santo andre
# Processing Record 38 of Set 5 | laurel
# Processing Record 39 of Set 5 | macapa
# Processing Record 40 of Set 5 | marsa matruh
# Processing Record 41 of Set 5 | port hedland
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 5 | nadvoitsy
# Processing Record 45 of Set 5 | straumen
# Processing Record 46 of Set 5 | tapes
# Processing Record 47 of Set 5 | bud
# Processing Record 48 of Set 5 | miri
# Processing Record 49 of Set 5 | bozdar
# Processing Record 50 of Set 5 | vengerovo
# Processing Record 1 of Set 6 | zhigansk
# Processing Record 2 of Set 6 | khatanga
# Processing Record 3 of Set 6 | fortuna
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | maniitsoq
# Processing Record 7 of Set 6 | porbandar
# Processing Record 8 of Set 6 | sabang
# Processing Record 9 of Set 6 | broome
# Processing Record 10 of Set 6 | roches noires
# City not found. Skipping...
# Processing Record 11 of Set 6 | savinka
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 6 | hofn
# Processing Record 15 of Set 6 | gornozavodsk
# Processing Record 16 of Set 6 | boyolangu
# Processing Record 17 of Set 6 | ayr
# Processing Record 18 of Set 6 | abilene
# Processing Record 19 of Set 6 | lardos
# Processing Record 20 of Set 6 | waingapu
# Processing Record 21 of Set 6 | flinders
# Processing Record 22 of Set 6 | mackay
# Processing Record 23 of Set 6 | mabaruma
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | kenai
# Processing Record 26 of Set 6 | kutum
# Processing Record 27 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 6 | olafsvik
# Processing Record 29 of Set 6 | lyuban
# Processing Record 30 of Set 6 | quatre cocos
# Processing Record 31 of Set 6 | ventspils
# Processing Record 32 of Set 6 | castro
# Processing Record 33 of Set 6 | manggar
# Processing Record 34 of Set 6 | nanortalik
# Processing Record 35 of Set 6 | ferkessedougou
# Processing Record 36 of Set 6 | vila velha
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | ayna
# Processing Record 42 of Set 6 | tupik
# Processing Record 43 of Set 6 | chumikan
# Processing Record 44 of Set 6 | iqaluit
# Processing Record 45 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 6 | luderitz
# Processing Record 49 of Set 6 | vrangel
# Processing Record 50 of Set 6 | aleksandrov gay
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | nhulunbuy
# Processing Record 3 of Set 7 | yumen
# Processing Record 4 of Set 7 | malanje
# Processing Record 5 of Set 7 | maroantsetra
# Processing Record 6 of Set 7 | karratha
# Processing Record 7 of Set 7 | camacupa
# Processing Record 8 of Set 7 | sao joao da barra
# Processing Record 9 of Set 7 | ahipara
# Processing Record 10 of Set 7 | rognan
# Processing Record 11 of Set 7 | atuona
# Processing Record 12 of Set 7 | santa isabel
# Processing Record 13 of Set 7 | koungou
# Processing Record 14 of Set 7 | waterloo
# Processing Record 15 of Set 7 | barranca
# Processing Record 16 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 7 | seymchan
# Processing Record 18 of Set 7 | acapulco
# Processing Record 19 of Set 7 | svetlogorsk
# Processing Record 20 of Set 7 | dekar
# Processing Record 21 of Set 7 | port hawkesbury
# Processing Record 22 of Set 7 | egvekinot
# Processing Record 23 of Set 7 | mindelo
# Processing Record 24 of Set 7 | naryan-mar
# Processing Record 25 of Set 7 | upernavik
# Processing Record 26 of Set 7 | talisay
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | balkhash
# Processing Record 29 of Set 7 | obodivka
# Processing Record 30 of Set 7 | havoysund
# Processing Record 31 of Set 7 | siddipet
# Processing Record 32 of Set 7 | urengoy
# Processing Record 33 of Set 7 | thompson
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | muhos
# Processing Record 36 of Set 7 | champasak
# Processing Record 37 of Set 7 | myitkyina
# Processing Record 38 of Set 7 | jumla
# Processing Record 39 of Set 7 | sumter
# Processing Record 40 of Set 7 | northam
# Processing Record 41 of Set 7 | polyarnyy
# Processing Record 42 of Set 7 | astana
# Processing Record 43 of Set 7 | sitka
# Processing Record 44 of Set 7 | baoqing
# Processing Record 45 of Set 7 | san isidro
# Processing Record 46 of Set 7 | victor harbor
# Processing Record 47 of Set 7 | vardo
# Processing Record 48 of Set 7 | aitape
# Processing Record 49 of Set 7 | banjar
# Processing Record 50 of Set 7 | harer
# Processing Record 1 of Set 8 | zhangjiakou
# Processing Record 2 of Set 8 | mayumba
# Processing Record 3 of Set 8 | deer lake
# Processing Record 4 of Set 8 | north bend
# Processing Record 5 of Set 8 | viedma
# Processing Record 6 of Set 8 | saint-junien
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 8 | sorkjosen
# Processing Record 10 of Set 8 | udachnyy
# Processing Record 11 of Set 8 | asekeyevo
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | cidreira
# Processing Record 14 of Set 8 | arraias
# Processing Record 15 of Set 8 | komsomolskiy
# Processing Record 16 of Set 8 | odesskoye
# Processing Record 17 of Set 8 | mount gambier
# Processing Record 18 of Set 8 | chokurdakh
# Processing Record 19 of Set 8 | filadelfia
# Processing Record 20 of Set 8 | kruisfontein
# Processing Record 21 of Set 8 | luau
# Processing Record 22 of Set 8 | richards bay
# Processing Record 23 of Set 8 | jalu
# Processing Record 24 of Set 8 | khovu-aksy
# Processing Record 25 of Set 8 | arman
# Processing Record 26 of Set 8 | bria
# Processing Record 27 of Set 8 | westport
# Processing Record 28 of Set 8 | tigil
# Processing Record 29 of Set 8 | sola
# Processing Record 30 of Set 8 | visby
# Processing Record 31 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 8 | mastic beach
# Processing Record 33 of Set 8 | anloga
# Processing Record 34 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 8 | saint-leu
# Processing Record 36 of Set 8 | praia da vitoria
# Processing Record 37 of Set 8 | codrington
# Processing Record 38 of Set 8 | russkaya polyana
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | khargapur
# Processing Record 41 of Set 8 | valleyview
# Processing Record 42 of Set 8 | buin
# Processing Record 43 of Set 8 | bulancak
# Processing Record 44 of Set 8 | cururupu
# Processing Record 45 of Set 8 | birjand
# Processing Record 46 of Set 8 | listvyanka
# Processing Record 47 of Set 8 | sawakin
# Processing Record 48 of Set 8 | lerik
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 50 of Set 8 | nalut
# Processing Record 1 of Set 9 | maarianhamina
# Processing Record 2 of Set 9 | metehara
# City not found. Skipping...
# Processing Record 3 of Set 9 | lavrentiya
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | sobolevo
# Processing Record 6 of Set 9 | blarney
# Processing Record 7 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 8 of Set 9 | qena
# Processing Record 9 of Set 9 | missoula
# Processing Record 10 of Set 9 | pochutla
# Processing Record 11 of Set 9 | nizwa
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | belmonte
# Processing Record 14 of Set 9 | ostrovnoy
# Processing Record 15 of Set 9 | avera
# Processing Record 16 of Set 9 | alice springs
# Processing Record 17 of Set 9 | san quintin
# Processing Record 18 of Set 9 | pacific grove
# Processing Record 19 of Set 9 | mahebourg
# Processing Record 20 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | reconquista
# Processing Record 22 of Set 9 | bara
# Processing Record 23 of Set 9 | aranos
# Processing Record 24 of Set 9 | matamoros
# Processing Record 25 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 9 | conceicao das alagoas
# Processing Record 27 of Set 9 | morant bay
# Processing Record 28 of Set 9 | micheweni
# Processing Record 29 of Set 9 | kyren
# Processing Record 30 of Set 9 | puqi
# Processing Record 31 of Set 9 | crotone
# Processing Record 32 of Set 9 | nyurba
# Processing Record 33 of Set 9 | dwarka
# Processing Record 34 of Set 9 | zheleznodorozhnyy
# Processing Record 35 of Set 9 | aras
# Processing Record 36 of Set 9 | chapais
# Processing Record 37 of Set 9 | broken hill
# Processing Record 38 of Set 9 | hay river
# Processing Record 39 of Set 9 | drayton valley
# Processing Record 40 of Set 9 | saint simons
# Processing Record 41 of Set 9 | antofagasta
# Processing Record 42 of Set 9 | archidona
# Processing Record 43 of Set 9 | yeniseysk
# Processing Record 44 of Set 9 | mangai
# Processing Record 45 of Set 9 | benguela
# Processing Record 46 of Set 9 | lata
# Processing Record 47 of Set 9 | abu dhabi
# Processing Record 48 of Set 9 | sao felix do xingu
# Processing Record 49 of Set 9 | limbang
# Processing Record 50 of Set 9 | kirakira
# Processing Record 1 of Set 10 | moose factory
# Processing Record 2 of Set 10 | coihaique
# Processing Record 3 of Set 10 | kota bahru
# Processing Record 4 of Set 10 | cumana
# Processing Record 5 of Set 10 | daru
# Processing Record 6 of Set 10 | leh
# Processing Record 7 of Set 10 | ambon
# Processing Record 8 of Set 10 | atbasar
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | kyra
# Processing Record 11 of Set 10 | thessalon
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | piacabucu
# Processing Record 14 of Set 10 | sept-iles
# Processing Record 15 of Set 10 | birao
# Processing Record 16 of Set 10 | egersund
# Processing Record 17 of Set 10 | meulaboh
# Processing Record 18 of Set 10 | muskogee
# Processing Record 19 of Set 10 | maridi
# Processing Record 20 of Set 10 | russell
# Processing Record 21 of Set 10 | saint-pierre
# Processing Record 22 of Set 10 | los llanos de aridane
# Processing Record 23 of Set 10 | huarmey
# Processing Record 24 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 25 of Set 10 | baturyn
# Processing Record 26 of Set 10 | parambu
# Processing Record 27 of Set 10 | kargasok
# Processing Record 28 of Set 10 | alyangula
# Processing Record 29 of Set 10 | mahenge
# Processing Record 30 of Set 10 | faranah
# Processing Record 31 of Set 10 | saurimo
# Processing Record 32 of Set 10 | aksarka
# Processing Record 33 of Set 10 | sukhumi
# Processing Record 34 of Set 10 | marawi
# Processing Record 35 of Set 10 | ewo
# Processing Record 36 of Set 10 | renala khurd
# Processing Record 37 of Set 10 | mao
# Processing Record 38 of Set 10 | ocos
# Processing Record 39 of Set 10 | qiongshan
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | muisne
# Processing Record 42 of Set 10 | atherton
# Processing Record 43 of Set 10 | teya
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | nola
# Processing Record 46 of Set 10 | gorontalo
# Processing Record 47 of Set 10 | sicamous
# Processing Record 48 of Set 10 | black river
# Processing Record 49 of Set 10 | orasac
# Processing Record 50 of Set 10 | campeche
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | port blair
# Processing Record 3 of Set 11 | yate
# Processing Record 4 of Set 11 | mugur-aksy
# Processing Record 5 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 11 | margate
# Processing Record 7 of Set 11 | aklavik
# Processing Record 8 of Set 11 | leningradskiy
# Processing Record 9 of Set 11 | aksay
# Processing Record 10 of Set 11 | obihiro
# Processing Record 11 of Set 11 | itoman
# Processing Record 12 of Set 11 | garland
# Processing Record 13 of Set 11 | severnoye
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | colares
# Processing Record 16 of Set 11 | boa vista
# Processing Record 17 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 11 | salym
# Processing Record 19 of Set 11 | murgab
# Processing Record 20 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 11 | bengbu
# Processing Record 22 of Set 11 | donskoye
# Processing Record 23 of Set 11 | rantepao
# Processing Record 24 of Set 11 | bay saint louis
# Processing Record 25 of Set 11 | aviles
# Processing Record 26 of Set 11 | rameswaram
# Processing Record 27 of Set 11 | roald
# Processing Record 28 of Set 11 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 29 of Set 11 | santa maria
# Processing Record 30 of Set 11 | fos-sur-mer
# Processing Record 31 of Set 11 | nadym
# Processing Record 32 of Set 11 | latung
# Processing Record 33 of Set 11 | dudinka
# Processing Record 34 of Set 11 | kalabo
# Processing Record 35 of Set 11 | monrovia
# Processing Record 36 of Set 11 | lorengau
# Processing Record 37 of Set 11 | jitra
# Processing Record 38 of Set 11 | penzance
# Processing Record 39 of Set 11 | mangrol
# Processing Record 40 of Set 11 | svatove
# Processing Record 41 of Set 11 | winnemucca
# Processing Record 42 of Set 11 | firminy
# Processing Record 43 of Set 11 | mount pleasant
# Processing Record 44 of Set 11 | mocuba
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | rabo de peixe
# Processing Record 47 of Set 11 | osoyoos
# Processing Record 48 of Set 11 | olbia
# Processing Record 49 of Set 11 | camopi
# Processing Record 50 of Set 11 | aberystwyth
# Processing Record 1 of Set 12 | tahta
# Processing Record 2 of Set 12 | hatton
# Processing Record 3 of Set 12 | nador
# Processing Record 4 of Set 12 | ilawa
# Processing Record 5 of Set 12 | san lazaro
# Processing Record 6 of Set 12 | balesti
# Processing Record 7 of Set 12 | villeneuve-sur-lot
# Processing Record 8 of Set 12 | glomfjord
# Processing Record 9 of Set 12 | naantali
# Processing Record 10 of Set 12 | lyaskelya
# Processing Record 11 of Set 12 | esso
# Processing Record 12 of Set 12 | bolobo
# Processing Record 13 of Set 12 | agidel
# Processing Record 14 of Set 12 | soyo
# Processing Record 15 of Set 12 | falam
# Processing Record 16 of Set 12 | amravati
# Processing Record 17 of Set 12 | batagay
# Processing Record 18 of Set 12 | gisborne
# Processing Record 19 of Set 12 | general salgado
# Processing Record 20 of Set 12 | brisbane
# Processing Record 21 of Set 12 | tarko-sale
# Processing Record 22 of Set 12 | mollendo
# Processing Record 23 of Set 12 | miandrivazo
# Processing Record 24 of Set 12 | te anau
# Processing Record 25 of Set 12 | kavaratti
# Processing Record 26 of Set 12 | umarga
# Processing Record 27 of Set 12 | tateyama
# Processing Record 28 of Set 12 | dandong
# Processing Record 29 of Set 12 | khani
# Processing Record 30 of Set 12 | townsville
# Processing Record 31 of Set 12 | pedregal
# Processing Record 32 of Set 12 | elbistan
# Processing Record 33 of Set 12 | deputatskiy
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | coahuayana
# Processing Record 36 of Set 12 | bell ville
# Processing Record 37 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 12 | minab
# Processing Record 39 of Set 12 | dong hoi
# Processing Record 40 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 12 | takoradi
# Processing Record 42 of Set 12 | banikoara
# Processing Record 43 of Set 12 | ulaanbaatar
# Processing Record 44 of Set 12 | millau
# Processing Record 45 of Set 12 | chicama
# Processing Record 46 of Set 12 | quang ngai
# Processing Record 47 of Set 12 | labuhan
# Processing Record 48 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 12 | gudalur
# Processing Record 50 of Set 12 | caramay
# Processing Record 1 of Set 13 | cedar city
# Processing Record 2 of Set 13 | gorele
# Processing Record 3 of Set 13 | mandalgovi
# Processing Record 4 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 13 | edd
# Processing Record 6 of Set 13 | touros
# Processing Record 7 of Set 13 | cockburn town
# Processing Record 8 of Set 13 | xichang
# Processing Record 9 of Set 13 | bitung
# Processing Record 10 of Set 13 | pedernales
# Processing Record 11 of Set 13 | naze
# Processing Record 12 of Set 13 | ballina
# Processing Record 13 of Set 13 | perpignan
# Processing Record 14 of Set 13 | gushikawa
# Processing Record 15 of Set 13 | natal
# Processing Record 16 of Set 13 | gillette
# Processing Record 17 of Set 13 | kayerkan
# Processing Record 18 of Set 13 | roma
# Processing Record 19 of Set 13 | isangel
# Processing Record 20 of Set 13 | omboue
# Processing Record 21 of Set 13 | juba
# Processing Record 22 of Set 13 | shelburne
# Processing Record 23 of Set 13 | havre
# Processing Record 24 of Set 13 | nara
# Processing Record 25 of Set 13 | severodvinsk
# Processing Record 26 of Set 13 | yar-sale
# Processing Record 27 of Set 13 | ngunguru
# Processing Record 28 of Set 13 | arandis
# Processing Record 29 of Set 13 | benicarlo
# Processing Record 30 of Set 13 | crixas
# Processing Record 31 of Set 13 | merauke
# Processing Record 32 of Set 13 | kerema
# Processing Record 33 of Set 13 | zarate
# Processing Record 34 of Set 13 | tharad
# Processing Record 35 of Set 13 | faya
# Processing Record 36 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 13 | sylva
# Processing Record 38 of Set 13 | beringovskiy
# Processing Record 39 of Set 13 | biryusinsk
# Processing Record 40 of Set 13 | kiruna
# Processing Record 41 of Set 13 | antonina
# Processing Record 42 of Set 13 | plettenberg bay
# Processing Record 43 of Set 13 | arcata
# Processing Record 44 of Set 13 | khvastovichi
# Processing Record 45 of Set 13 | marsh harbour
# Processing Record 46 of Set 13 | cabedelo
# Processing Record 47 of Set 13 | domoni
# Processing Record 48 of Set 13 | whitecourt
# Processing Record 49 of Set 13 | imeni poliny osipenko
# Processing Record 50 of Set 13 | corralillo
# Processing Record 1 of Set 14 | dzialdowo
# Processing Record 2 of Set 14 | nyagan
# Processing Record 3 of Set 14 | lethem
# Processing Record 4 of Set 14 | tiznit
# Processing Record 5 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 6 of Set 14 | portland
# Processing Record 7 of Set 14 | thai binh
# Processing Record 8 of Set 14 | villa maria
# Processing Record 9 of Set 14 | kapit
# Processing Record 10 of Set 14 | rafaela
# Processing Record 11 of Set 14 | ilulissat
# Processing Record 12 of Set 14 | anadyr
# Processing Record 13 of Set 14 | artyom
# Processing Record 14 of Set 14 | neu-anspach
# Processing Record 15 of Set 14 | tysmenytsya
# Processing Record 16 of Set 14 | alghero
# Processing Record 17 of Set 14 | pytalovo
# Processing Record 18 of Set 14 | folkestone
# Processing Record 19 of Set 14 | wanning
# Processing Record 20 of Set 14 | savinskiy
# Processing Record 21 of Set 14 | karla
# Processing Record 22 of Set 14 | karonga
# Processing Record 23 of Set 14 | borovskoy
# Processing Record 24 of Set 14 | kisangani
# Processing Record 25 of Set 14 | rosarito
# Processing Record 26 of Set 14 | atocha
# Processing Record 27 of Set 14 | bardiyah
# Processing Record 28 of Set 14 | thunder bay
# Processing Record 29 of Set 14 | karaton
# Processing Record 30 of Set 14 | forbes
# Processing Record 31 of Set 14 | mildura
# Processing Record 32 of Set 14 | veraval
# Processing Record 33 of Set 14 | goderich
# Processing Record 34 of Set 14 | zyryanka
# Processing Record 35 of Set 14 | yataity
# Processing Record 36 of Set 14 | loja
# Processing Record 37 of Set 14 | dullewala
# Processing Record 38 of Set 14 | galveston
# Processing Record 39 of Set 14 | makakilo city
# Processing Record 40 of Set 14 | zhaoqing
# Processing Record 41 of Set 14 | teahupoo
# Processing Record 42 of Set 14 | conde
# Processing Record 43 of Set 14 | shuiji
# Processing Record 44 of Set 14 | agirish
# Processing Record 45 of Set 14 | kimberley
# Processing Record 46 of Set 14 | otane
# Processing Record 47 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 14 | hamilton
# Processing Record 49 of Set 14 | wenling
# Processing Record 50 of Set 14 | saint-francois
# Processing Record 1 of Set 15 | bavly
# Processing Record 2 of Set 15 | solhan
# Processing Record 3 of Set 15 | westerland
# Processing Record 4 of Set 15 | kamenka
# Processing Record 5 of Set 15 | xuddur
# Processing Record 6 of Set 15 | okha
# Processing Record 7 of Set 15 | povenets
# Processing Record 8 of Set 15 | hendrina
# Processing Record 9 of Set 15 | port keats
# Processing Record 10 of Set 15 | karaman
# Processing Record 11 of Set 15 | balkanabat
# Processing Record 12 of Set 15 | panaba
# Processing Record 13 of Set 15 | gunib
# Processing Record 14 of Set 15 | koryazhma
# Processing Record 15 of Set 15 | kormilovka
# Processing Record 16 of Set 15 | vicuna
# Processing Record 17 of Set 15 | narsaq
# Processing Record 18 of Set 15 | port augusta
# Processing Record 19 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 15 | marfino
# Processing Record 21 of Set 15 | savannah bight
# Processing Record 22 of Set 15 | ardakan
# Processing Record 23 of Set 15 | tchaourou
# Processing Record 24 of Set 15 | ulaangom
# Processing Record 25 of Set 15 | nizhniy ingash
# Processing Record 26 of Set 15 | marshall
# Processing Record 27 of Set 15 | katakwi
# Processing Record 28 of Set 15 | san buenaventura
# Processing Record 29 of Set 15 | atar
# Processing Record 30 of Set 15 | lagunas
# Processing Record 31 of Set 15 | argelia
# Processing Record 32 of Set 15 | milingimbi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
# 7 Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo      US  19.7297 -155.0900     84.27        71           1
# 1       Busselton      AU -33.6500  115.3333     58.08        70          74
# 2     Yellowknife      CA  62.4560 -114.3525     47.41        99          20
# 3          Albany      US  42.6001  -73.9662     51.53        88          12
# 4             Gat      IL  31.6100   34.7642     74.08       100          32
# 5       Cape Town      ZA -33.9258   18.4232     57.27        74          75
# 6       Saskylakh      RU  71.9167  114.0833     21.92        96          93
# 7  Cabo San Lucas      MX  22.8909 -109.9124     85.51        76           1
# 8        Hermanus      ZA -34.4187   19.2345     54.90        86          39
# 9          Burnie      AU -41.0667  145.9167     57.00        93         100
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1       14.85       broken clouds
# 2        4.00          few clouds
# 3        4.45          few clouds
# 4        4.12    scattered clouds
# 5        4.61          light rain
# 6        3.80     overcast clouds
# 7        4.61           clear sky
# 8       11.05          light rain
# 9        2.68       moderate rain

# %%
# 8 In World_Weather_Analysis folder, create a new folder called "Weather_Database."

# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
